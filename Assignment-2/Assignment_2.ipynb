# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
# load the api key from the environment variables

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
# make a llm call to the open router api using the api key
llm = ChatOpenAI(
    model="gpt-4o-mini", 
    api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
    )

# %% [markdown]
# 1. Zero shot Prompting

# %%
zero_shot_prompt = """
Classify the sentiment:
Text: The product quality is excellent.
"""
result = llm.invoke(zero_shot_prompt)

print("Zero-shot Output:\n", result.content)
# Out:
# Zero-shot Output:
#  The sentiment of the text is positive.

# %% [markdown]
# 2. Few-Shot Prompting

# %%
few_shot_prompt = """
Text: I loved the service -> Positive
Text: The food was awful -> Negative
Text: The delivery was late ->
"""

result = llm.invoke(few_shot_prompt)
print("Few-shot Output:\n", result.content)
# Out:
# Few-shot Output:
#  Negative

# %% [markdown]
# 3. Chain-of-Thought Prompting (CoT)

# %%
cot_prompt = """
Solve step-by-step:
A shop sells 15 pens per day at ₹10 each.
What is revenue for 7 days?
Explain reasoning step by step.
"""

result = llm.invoke(cot_prompt)
print("CoT Output:\n", result.content)
# Out:
# CoT Output:
#  To find the revenue generated by the shop in 7 days from selling pens, we can follow these steps:
#
# 1. **Identify the daily sales**:
#    The shop sells 15 pens per day.
#
# 2. **Determine the price per pen**:
#    Each pen is sold for ₹10.
#
# 3. **Calculate daily revenue**:
#    To find the revenue generated in one day, we multiply the number of pens sold by the price per pen:
#    \[
#    \text{Daily Revenue} = \text{Number of Pens Sold} \times \text{Price per Pen}
#    \]
#    Substituting the known values:
#    \[
#    \text{Daily Revenue} = 15 \text{ pens} \times ₹10/\text{pen} = ₹150
#    \]
#
# 4. **Calculate revenue over 7 days**:
#    Since the shop sells the same amount every day, we can find the revenue for 7 days by multiplying the daily revenue by 7:
#    \[
#    \text{Revenue for 7 days} = \text{Daily Revenue} \times 7
#    \]
#    Substituting the daily revenue we calculated:
#    \[
#    \text{Revenue for 7 days} = ₹150 \times 7 = ₹1050
#    \]
#
# 5. **Final conclusion**:
#    Therefore, the total revenue from selling pens over 7 days is ₹1050.
#
# So, the final answer is:
# \[
# \text{Total Revenue for 7 days} = ₹1050
# \]

# %% [markdown]
# 4. Tree-of-Thought Prompting (ToT)

# %%
tot_prompt = """
Generate three different strategies to market a new mobile app.
Evaluate pros and cons of each.
Select the best strategy with justification.
"""
result = llm.invoke(tot_prompt)
print("ToT Output:\n", result.content)
# Out:
# ToT Output:
#  Here are three different strategies to market a new mobile app, along with their respective pros and cons.
#
# ### Strategy 1: Influencer Marketing
#
# **Description:** Partner with social media influencers or content creators who align with the app’s target audience to promote the app through reviews, tutorials, or sponsored posts.
#
# #### Pros:
# - **Wide Reach:** Influencers have established audiences, which means potential exposure to a large number of potential users.
# - **Trust and Credibility:** Influencers often have a loyal following that trusts their recommendations, leading to higher conversion rates.
# - **Targeted Audience:** By selecting influencers relevant to the app's niche, marketing can be more focused and effective.
#
# #### Cons:
# - **Cost:** High-profile influencers can be expensive; even mid-level influencers may require significant budget allocation.
# - **Brand Mismatch:** If the influencer’s image doesn’t align with the app, it may negatively impact the brand's reputation.
# - **ROI Uncertainty:** Measuring the direct return on investment can be challenging, making it risky.
#
# ### Strategy 2: In-App Advertising and Promotions
#
# **Description:** Utilize in-app ads on various platforms (social media, other apps) and consider introductory offers like free trials or discounted subscriptions to encourage downloads.
#
# #### Pros:
# - **Immediate Visibility:** In-app advertising can quickly reach potential users in environments where they are already engaged.
# - **Targeting Capabilities:** Advertising platforms enable targeting based on user demographics, interests, and behaviors, increasing the chances of reaching the right audience.
# - **Control Over Costs:** Budgeting for ads can be managed effectively, allowing for scaling based on performance.
#
# #### Cons:
# - **Ad Fatigue:** Users may become desensitized to ads, leading to decreased effectiveness over time.
# - **Ad Blockers:** Some users may have ad blockers enabled, reducing potential reach.
# - **Competition:** High competition in ad spaces can lead to increased costs per click/impression.
#
# ### Strategy 3: Content Marketing through a Blog or Video Content
#
# **Description:** Create valuable content related to the app's purpose—such as blog posts, tutorial videos, or webinars—that attracts and educates potential users.
#
# #### Pros:
# - **Organic Traffic:** Quality content can improve search engine rankings, attracting more users without direct advertising costs.
# - **Relationship Building:** Engaging content builds trust with the audience and fosters community, which may lead to loyal users.
# - **Cost-Effective Long-Term:** The initial investment can provide long-term benefits, as evergreen content continues to attract users over time.
#
# #### Cons:
# - **Time-Intensive:** Content marketing requires careful planning, creation, and regular updates, which can take significant time and resources.
# - **Slow Growth:** Unlike paid advertising, results from content marketing may take a while to materialize, leading to a slower initial user acquisition.
# - **Consistency Required:** To gain traction, consistent quality content is necessary, which can be challenging to maintain.
#
# ### Recommended Strategy: Influencer Marketing
#
# **Justification:**
# Influencer marketing strikes a balance between reach and credibility, making it a strong choice for new app launches. Although it may involve higher upfront costs, the trust that influencers command can lead to significant user acquisition and engagement, especially if the app is visually appealing or requires demonstration (like a game or creative tool). Additionally, with social media being a potent platform for app discovery, leveraging influencers who resonate with the target demographic can create buzz and virality around the app.
#
# Ultimately, integrating influencer marketing with elements of content marketing can further amplify reach and depth, offering an even more robust strategy for app promotion.

# %% [markdown]
# 5. Interview Prompting Approach

# %%
interview_prompt = """
Answer the following sequential questions:

1. What problem does an online grocery app solve?
2. Who are the target users?
3. What are the main challenges?
4. Based on above answers, evaluate feasibility.
"""

result = llm.invoke(interview_prompt)
print("Interview Output:\n", result.content)
# Out:
# Interview Output:
#  Certainly! Let's break down the questions sequentially:
#
# 1. **What problem does an online grocery app solve?**
#    An online grocery app addresses several problems, including:
#    - **Convenience**: It allows users to shop for groceries from the comfort of their homes, saving time and effort spent on physical trips to grocery stores.
#    - **Accessibility**: It provides access to a wide range of products, catering to those who may have mobility issues or live in areas with limited grocery options.
#    - **Time Management**: Users can shop quickly, often utilizing features like search, filters, and saved shopping lists to streamline the process.
#    - **Inventory Management**: It can help users keep track of what they need to buy and offer recommendations based on past purchases or dietary preferences.
#    - **Price Comparison**: Users can compare prices across different brands and stores easily to find the best deals.
#
# 2. **Who are the target users?**
#    The target users of an online grocery app may include:
#    - **Busy Professionals**: Individuals who have limited time for grocery shopping due to work commitments.
#    - **Families**: Households with multiple members who need to plan and purchase groceries regularly.
#    - **Health-Conscious Consumers**: Those who prefer to make healthier choices by having access to a variety of products with dietary information.
#    - **Elderly or Disabled Individuals**: Users who may face challenges in physically shopping for groceries.
#    - **Tech-Savvy Millennials and Gen Z**: Younger generations who are comfortable with technology and prefer online shopping experiences.
#
# 3. **What are the main challenges?**
#    The main challenges associated with online grocery apps include:
#    - **Logistics**: Managing delivery logistics efficiently to ensure timely delivery while maintaining the quality of perishable items.
#    - **Inventory Management**: Keeping real-time inventory updated to avoid issues such as out-of-stock items after an order is placed.
#    - **User Experience**: Designing a user-friendly interface that makes it easy for customers to find and order products.
#    - **Customer Trust**: Building trust regarding product quality, especially for fresh produce, and providing a clear return policy for unsatisfactory items.
#    - **Competition**: Competing with established grocery chains and other online platforms, which may require substantial marketing efforts and pricing strategies.
#
# 4. **Based on above answers, evaluate feasibility.**
#    - **Operational Feasibility**: With the right partnerships with local grocery suppliers and a robust logistics network, operational feasibility is high. However, investment in technology and infrastructure is crucial for successful inventory management and delivery logistics.
#    - **Market Feasibility**: The market for online grocery shopping has been growing, especially post-pandemic, showing increasing consumer acceptance. With a focus on the right target demographic, a reasonable demand exists.
#    - **Financial Feasibility**: Initial costs can be significant, including app development, marketing, and managing delivery operations. However, if a sustainable business model is adopted (e.g., subscription services, partnerships with local farms), long-term profitability is achievable.
#    - **Technical Feasibility**: Developing a reliable, user-friendly app is technically feasible given the current advancements in app development technologies. Integrating payment systems and delivery tracking is standard practice.
#
# Overall, based on these evaluations, launching an online grocery app can be feasible but requires careful planning and execution to address the inherent challenges in logistics, user experience, and market competition.
